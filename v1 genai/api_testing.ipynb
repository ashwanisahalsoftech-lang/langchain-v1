# %% [markdown]
# api testing

# %%
from langchain_groq import ChatGroq
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model("groq:qwen/qwen3-32b")

# %%
model
# Out:
# ChatGroq(output_version=None, profile={}, client=<groq.resources.chat.completions.Completions object at 0x0000014BC2DCE210>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x0000014BC2DCEC10>, model_name='groq/compound', model_kwargs={}, groq_api_key=SecretStr('**********'), groq_api_base=None, groq_proxy=None)

# %%
resp=model.invoke("weather of ahmedabad today")

# %%
print(resp.content)
# Out:
# **Weather in Ahmedabad (today, 4 May 2026)**
#
# | Parameter | Value |
# |-----------|-------|
# | **Condition** | Overcast |
# | **Temperature** | 36 °C (feels like 35 °C) |
# | **Humidity** | 39 % |
# | **Wind** | 22 km/h from the SW (226°); gusts up to 7 m/s |
# | **UV Index** | 2.7 – moderate |
# | **Air Pressure** | 1002 mb |
# | **Cloud Cover** | 0 % (clear sky despite “overcast” label) |
# | **Visibility** | 4 km |
# | **Precipitation** | 0 mm (0 % chance of rain) |
# | **Today's high / low** | 42 °C / 28 °C |
#
# ### Short‑term outlook
# - No rain is expected today; the sky will remain dry.
# - Temperatures will rise to a maximum of about **42 °C** and fall to a minimum of **28 °C** by night.
# - UV exposure is moderate; sunscreen is advisable if you’ll be outdoors for extended periods.
#
# ### 10‑day outlook (summary)
# | Date | Expected Temp. (°C) | Humidity | Condition |
# |------|--------------------|----------|-----------|
# | 4 May (today) | 33 – 36 | ~39 % | Overcast / Sunny |
# | 5 May | 34 | 40 % | Sunny |
# | 6 May | 34 | 42 % | Sunny |
# | 7 May | 34 | 41 % | Sunny |
# | 8 May | 35 | 37 % | Sunny |
# | 9 May | 35 | 36 % | Sunny |
# |10 May | 35 | 35 % | Sunny |
# |11 May | 36 | 36 % | Sunny |
# |12 May | 34 | 44 % | Sunny |
# |13 May | 35 | 34 % | Patchy rain possible (still low probability) |
#
# ### Key take‑aways
# - **Heat:** Temperatures are high (mid‑30s °C) with a peak near 42 °C, so stay hydrated and avoid prolonged exposure to direct sun during the hottest hours.
# - **No rain:** Precipitation is zero today and the chance of rain remains negligible for the next several days.
# - **Air quality:** While not detailed here, hot, dry conditions can sometimes elevate particulate matter; consider checking a dedicated air‑quality index if you have respiratory sensitivities.
#
# *Sources: AQI.in weather page for Ahmedabad (observations at 04:00 PM 4 May 2026) and supporting forecasts from India Today, NDTV, and other local weather services.*

# %% [markdown]
# #Gemini APi testing

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
load_dotenv()
os.environ["GEMINI_API_KEY"]=os.getenv("GEMINI_API_KEY")

# %%
model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash-lite",
    temperature=1.0,  # Gemini 3.0+ defaults to 1.0
    max_tokens=None,
    timeout=None,
    max_retries=2,
)

# %%
resp=model.invoke("weather of ahmedabad today")
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File c:\Users\SOFT\Downloads\lanchan v1\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:3071, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3070 try:
# -> 3071     response: GenerateContentResponse = self.client.models.generate_content(
#    3072         **request,
#    3073     )
#    3074 except ClientError as e:
#
# File c:\Users\SOFT\Downloads\lanchan v1\.venv\Lib\site-packages\google\genai\models.py:6329, in Models.generate_content(self, model, contents, config)
#    6328 i += 1
# -> 6329 response = self._generate_content(
#    6330     model=model, contents=contents, config=parsed_config
#    6331 )
#    6333 function_map = _extra_utils.get_function_map(parsed_config)
#
# File c:\Users\SOFT\Downloads\lanchan v1\.venv\Lib\site-packages\google\genai\models.py:4767, in Models._generate_content(self, model, contents, config)
#    4765 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4767 response = self._api_client.request(
#    4768     'post', path, request_dict, http_options
#    4769 )
#    4771 if config is not None and getattr(
#    4772     config, 'should_return_http_response', None
#    4773 ):
#
# File c:\Users\SOFT\Downloads\lanchan v1\.venv\Lib\site-packages\google\genai\_api_client.py:1579, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1576 http_request = self._build_request(
#    1577     http_method, path, request_dict, http_options
#    1578 )
# -> 1579 response = self._request(http_request, http_options, stream=False)
#    1580 response_body = (
#    1581     response.response_stream[0] if response.response_stream else ''
#    1582 )
#
# File c:\Users\SOFT\Downloads\lanchan v1\.venv\Lib\site-packages\google\genai\_api_client.py:1370, in BaseApiClient._request(self, http_request, http_options, stream)
#    1369     retry = tenacity.Retrying(**retry_kwargs)
# -> 1370     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1372 return self._retry(self._request_once, http_request, stream)
#
# File c:\Users\SOFT\Downloads\lanchan v1\.venv\Lib\site-packages\tenacity\__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#
# File c:\Users\SOFT\Downloads\lanchan v1\.venv\Lib\site-packages\tenacity\__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File c:\Users\SOFT\Downloads\lanchan v1\.venv\Lib\site-packages\tenacity\__init__.py:393, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     392 if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 393     self._add_action_func(lambda rs: rs.outcome.result())
#     394     return
#
# File C:\Program Files\Python314\Lib\concurrent\futures\_base.py:443, in Future.result(self, timeout)
#     442 elif self._state == FINISHED:
# --> 443     return self.__get_result()
#     445 self._condition.wait(timeout)
#
# File C:\Program Files\Python314\Lib\concurrent\futures\_base.py:395, in Future.__get_result(self)
#     394 try:
# --> 395     raise self._exception
#     396 finally:
#     397     # Break a reference cycle with the exception in self._exception
#
# File c:\Users\SOFT\Downloads\lanchan v1\.venv\Lib\site-packages\tenacity\__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     472 try:
# --> 473     result = fn(*args, **kwargs)
#     474 except BaseException:  # noqa: B902
#
# File c:\Users\SOFT\Downloads\lanchan v1\.venv\Lib\site-packages\google\genai\_api_client.py:1349, in BaseApiClient._request_once(self, http_request, stream)
#    1348   response = self._httpx_client.send(httpx_request, stream=stream)  # type: ignore[union-attr]
# -> 1349 errors.APIError.raise_for_response(response)
#    1350 return HttpResponse(
#    1351     response.headers, response if stream else [response.text]
#    1352 )
#
# File c:\Users\SOFT\Downloads\lanchan v1\.venv\Lib\site-packages\google\genai\errors.py:155, in APIError.raise_for_response(cls, response)
#     153   response_json = response.body_segments[0].get('error', {})
# --> 155 cls.raise_error(response.status_code, response_json, response)
#
# File c:\Users\SOFT\Downloads\lanchan v1\.venv\Lib\site-packages\google\genai\errors.py:184, in APIError.raise_error(cls, status_code, response_json, response)
#     183 if 400 <= status_code < 500:
# --> 184   raise ClientError(status_code, response_json, response)
#     185 elif 500 <= status_code < 600:
#
# ClientError: 403 PERMISSION_DENIED. {'error': {'code': 403, 'message': 'Your project has been denied access. Please contact support.', 'status': 'PERMISSION_DENIED'}}
#
# The above exception was the direct cause of the following exception:
#
# ChatGoogleGenerativeAIError               Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 resp=model.invoke("weather of ahmedabad today")
#
# File c:\Users\SOFT\Downloads\lanchan v1\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:2559, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    2556         msg = "Tools are already defined.code_execution tool can't be defined"
#    2557         raise ValueError(msg)
# -> 2559 return super().invoke(input, config, stop=stop, **kwargs)
#
# File c:\Users\SOFT\Downloads\lanchan v1\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:471, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     457 @override
#     458 def invoke(
#     459     self,
#    (...)    464     **kwargs: Any,
#     465 ) -> AIMessage:
#     466     config = ensure_config(config)
#     467     return cast(
#     468         "AIMessage",
#     469         cast(
#     470             "ChatGeneration",
# --> 471             self.generate_prompt(
#     472                 [self._convert_input(input)],
#     473                 stop=stop,
#     474                 callbacks=config.get("callbacks"),
#     475                 tags=config.get("tags"),
#     476                 metadata=config.get("metadata"),
#     477                 run_name=config.get("run_name"),
#     478                 run_id=config.pop("run_id", None),
#     479                 **kwargs,
#     480             ).generations[0][0],
#     481         ).message,
#     482     )
#
# File c:\Users\SOFT\Downloads\lanchan v1\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1749, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1740 @override
#    1741 def generate_prompt(
#    1742     self,
#    (...)   1746     **kwargs: Any,
#    1747 ) -> LLMResult:
#    1748     prompt_messages = [p.to_messages() for p in prompts]
# -> 1749     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\SOFT\Downloads\lanchan v1\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1556, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1553 for i, m in enumerate(input_messages):
#    1554     try:
#    1555         results.append(
# -> 1556             self._generate_with_cache(
#    1557                 m,
#    1558                 stop=stop,
#    1559                 run_manager=run_managers[i] if run_managers else None,
#    1560                 **kwargs,
#    1561             )
#    1562         )
#    1563     except BaseException as e:
#    1564         if run_managers:
#
# File c:\Users\SOFT\Downloads\lanchan v1\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1896, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1894     result = generate_from_stream(iter(chunks))
#    1895 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1896     result = self._generate(
#    1897         messages, stop=stop, run_manager=run_manager, **kwargs
#    1898     )
#    1899 else:
#    1900     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\SOFT\Downloads\lanchan v1\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:3075, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3071     response: GenerateContentResponse = self.client.models.generate_content(
#    3072         **request,
#    3073     )
#    3074 except ClientError as e:
# -> 3075     _handle_client_error(e, request)
#    3077 return _response_to_result(response)
#
# File c:\Users\SOFT\Downloads\lanchan v1\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:166, in _handle_client_error(e, request)
#     164 model_name = request.get("model", "unknown")
#     165 msg = f"Error calling model '{model_name}' ({e.status}): {e}"
# --> 166 raise ChatGoogleGenerativeAIError(msg) from e
#
# ChatGoogleGenerativeAIError: Error calling model 'gemini-2.5-flash-lite' (PERMISSION_DENIED): 403 PERMISSION_DENIED. {'error': {'code': 403, 'message': 'Your project has been denied access. Please contact support.', 'status': 'PERMISSION_DENIED'}}
