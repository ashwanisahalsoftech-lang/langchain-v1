# %%
from langchain_groq import ChatGroq
from dotenv import load_dotenv
import os
load_dotenv()
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

# %%
from langchain.tools import tool
from langchain.chat_models import init_chat_model
model = init_chat_model("groq:qwen/qwen3-32b")

# %%
@tool("personal_info")
def myinfo():
    """Information about myself:my name is sayyam , 20 year old agentic ai learner ,i m pursuing btech from lj university , my height is 5'9 , skin complexion:fair"""
model_tool1=model.bind_tools([myinfo])
resp=model_tool1.invoke("Whats my name")
resp
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[9], line 5
#       1 @tool("personal_info")
#       2 def myinfo():
#       3     """Information about myself:my name is sayyam , 20 year old agentic ai learner ,i m pursuing btech from lj university , my height is 5'9 , skin complexion:fair"""
#       4 model_tool1=model.bind_tools([myinfo])
# ----> 5 resp=model_tool1.invoke("Whats my name")
#       6 resp
#
# File c:\Users\SOFT\Downloads\lanchan v1\.venv\Lib\site-packages\langchain_core\runnables\base.py:5739, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5732 @override
#    5733 def invoke(
#    5734     self,
#    (...)   5737     **kwargs: Any | None,
#    5738 ) -> Output:
# -> 5739     return self.bound.invoke(
#    5740         input,
#    5741         self._merge_configs(config),
#    5742         **{**self.kwargs, **kwargs},
#    5743     )
#
# ...
